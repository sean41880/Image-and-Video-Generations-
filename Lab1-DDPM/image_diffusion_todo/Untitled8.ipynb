# %%
# !git clone https://github.com/sean41880/Image-and-Video-Generations-.git
# Out:
# Cloning into 'Image-and-Video-Generations-'...
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 71 (delta 7), reused 11 (delta 4), pack-reused 56 (from 2)
# Receiving objects: 100% (71/71), 126.52 MiB | 15.16 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
import os

# Replace 'Image-and-Video-Generations-' with the actual directory name if it's different
directory_name = 'Image-and-Video-Generations-'
os.chdir(directory_name)

print(f"已切換到目錄: {os.getcwd()}")
# Out:
# 已切換到目錄: /content/Image-and-Video-Generations-/Lab1-DDPM/image_diffusion_todo/Image-and-Video-Generations-/Lab1-DDPM/image_diffusion_todo/Image-and-Video-Generations-

# %%
os.chdir('Lab1-DDPM')

# %%
# !pip install scikit-learn

# %%
# Install requirements excluding scikit-learn
# !grep -v "scikit-learn" requirements.txt > requirements_no_sklearn.txt
# !pip install -r requirements_no_sklearn.txt

# %%
os.chdir('image_diffusion_todo')

# %%
drive_checkpoint_path = '/content/drive/MyDrive/results'
# !python train.py --mode linear --predictor mean --checkpoint_dir {drive_checkpoint_path}
# Out:
# usage: train.py [-h] [--gpu GPU] [--batch_size BATCH_SIZE]
#                 [--train_num_steps TRAIN_NUM_STEPS]
#                 [--warmup_steps WARMUP_STEPS] [--log_interval LOG_INTERVAL]
#                 [--max_num_images_per_cat MAX_NUM_IMAGES_PER_CAT]
#                 [--num_diffusion_train_timesteps NUM_DIFFUSION_TRAIN_TIMESTEPS]
#                 [--beta_1 BETA_1] [--beta_T BETA_T] [--seed SEED]
#                 [--image_resolution IMAGE_RESOLUTION]
#                 [--sample_method SAMPLE_METHOD] [--use_cfg]
#                 [--cfg_dropout CFG_DROPOUT] [--predictor {noise,x0,mean}]
#                 [--mode {linear,cosine,quad}]
# train.py: error: unrecognized arguments: --checkpoint_dir /content/drive/MyDrive/results
